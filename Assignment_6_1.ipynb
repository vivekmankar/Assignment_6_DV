# %%
import pandas as pd 
Location = "datasets/gradedata.csv"
df = pd.read_csv(Location) 
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
df_sort = df.sort_values(by=['fname', 'age' , 'grade'],ascending=[True, True, True])

# %%
df_sort[['fname','age','grade']]
# Out:
#          fname  age  grade
# 435      Aaron   16   88.7
# 721      Aaron   19   86.7
# 340      Abbot   16   58.9
# 1690     Abbot   16   81.0
# 1901     Abbot   16   87.5
# 817      Abbot   17   82.3
# 836       Abel   18   68.2
# 771    Abigail   14   81.5
# 1597      Abra   15   71.7
# 1159      Abra   16   80.1
# 1326   Abraham   16   73.3
# 643    Abraham   18   73.7
# 1133   Abraham   19   62.6
# 1436     Acton   14   67.0
# 813      Acton   18   70.8
# 1174     Acton   19   79.5
# 1117      Adam   14   70.1
# 1344      Adam   14   82.7
# 785       Adam   15   68.3
# 216       Adam   18   74.9
# 1729      Adam   19   88.2
# 1581     Adara   15   68.2
# 1254     Adara   15   98.5
# 1414   Addison   14   91.1
# 837    Addison   15   76.0
# 1169   Addison   16   81.8
# 1933     Adena   14  100.0
# 1990     Adena   17   70.2
# 855      Adena   17   80.2
# 445      Adria   19   76.8
# ...        ...  ...    ...
# 1947    Yvette   14   72.8
# 467     Yvette   18   89.8
# ...
